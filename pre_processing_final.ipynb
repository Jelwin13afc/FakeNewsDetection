# %% [markdown]
# <a href="https://colab.research.google.com/github/Jelwin13afc/FakeNewsDetection/blob/master/pre_processing_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Jelwin13afc/FakeNewsDetection
# Out:
# fatal: destination path 'FakeNewsDetection' already exists and is not an empty directory.

# %%
import json
import pandas as pd
import re
with open('/content/FakeNewsDetection/fake_news-all.json') as f:
  fake_news = json.load(f)
  #json to dataframe
  fake_news = pd.json_normalize(fake_news,'fake_news')
  f.close()

with open('/content/FakeNewsDetection/true_news_all_dirty.json') as f:
  true_news = json.load(f)
  #json to dataframe
  true_news = pd.json_normalize(true_news,'true_news')
  f.close()

# %%
# look for null values
fake_news.isnull().sum(axis = 0)
# Out:
# url                  0
# short_description    0
# full_title           5
# long_description     9
# dtype: int64

# %%
# look for null values
true_news.isnull().sum(axis = 0)
# Out:
# name                  0
# url                 120
# short_desc          133
# full_title          450
# long_description    450
# dtype: int64

# %%
true_news = true_news.rename(columns={'short_desc': 'short_description'})

# %%
true_news
# Out:
#                                                   name  ...                                   long_description
# 0    मोहम्मद सिराज ने हाल में पिता को खो दिया था ले...  ...                                                NaN
# 1    ब्रिसबेन टेस्ट का वो पल जब पुजारा के पापा डर ग...  ...                                                NaN
# 2    पाकिस्तान के टीवी एंकर इक़रारुल हसन ने भारत की...  ...                                                NaN
# 3                   कहां हुई थी पहली गणतंत्र दिवस परेड  ...  26 जनवरी: गणतंत्र दिवस की पहली परेड कहां हुई थ...
# 4                             कार्टून: सख़्त ज़रूरत है  ...  कार्टून: सख़्त ज़रूरत है\n4 घंटे पहले\nइमेज स्...
# ..                                                 ...  ...                                                ...
# 888  ब्रह्मोस एक्सटेंडड रेंज सुपरसोनिक क्रूज़ मिसाइ...  ...                                                NaN
# 889      भोलू पहलवानों को भारत क्यों नहीं आने दिया था?  ...                                                NaN
# 890  बिहार: जातीय समीकरणों और बीजेपी के हिंदुत्व का...  ...                                                NaN
# 891  स्टेन स्वामी: सबसे बुजुर्ग शख़्स जिन पर लगा आत...  ...                                                NaN
# 892  चीन के साथ संघर्ष हुआ तो भारत का कितना साथ देग...  ...                                                NaN
#
# [893 rows x 5 columns]

# %%
fake_news
# Out:
#                                                     url  ...                                   long_description
# 0     https://hindi.boomlive.in/fact-check/imran-kha...  ...  A video is viral with the claim that Pakistan ...
# 1     https://hindi.boomlive.in/fact-check/hindi-imp...  ...  सिख समुदाय के कुछ लोगों को हिंदी साइन बोर्ड पर...
# 2     https://hindi.boomlive.in/fact-check/pm-narend...  ...  प्रधानमंत्री नरेंद्र मोदी की एक़ तस्वीर सोशल मी...
# 3     https://hindi.boomlive.in/fact-check/rajnath-s...  ...                                                NaN
# 4     https://hindi.boomlive.in/fact-check/balakot-s...  ...  न्यूज़ संस्थान एशियन न्यूज़ इंटरनेशनल के साथ साथ...
# ...                                                 ...  ...                                                ...
# 1245  https://hindi.boomlive.in/%E0%A4%AD%E0%A4%BE%E...  ...  सोशल मीडिया पर एक फ्री स्टाइल महिला पहलवान का ...
# 1246  https://hindi.boomlive.in/%E0%A4%85%E0%A4%B8%E...  ...  एटीएम मशीन के अंदर फटे नोटों की ये तस्वीर व्हा...
# 1247  https://hindi.boomlive.in/%E0%A4%AA%E0%A5%87%E...  ...  अभिनेता से सांसद बने परेश रावल ट्विटर पर फेक न...
# 1248  https://hindi.boomlive.in/%E0%A4%95%E0%A4%B0%E...  ...  कर्नाटक चुनाव के दौर में जो ढेरों वेबसाइटस देख...
# 1249  https://hindi.boomlive.in/%E0%A4%AC%E0%A4%BF%E...  ...  प्रधानमंत्री नरेंद्र मोदी ने बिहार के मोतिहारी...
#
# [1250 rows x 4 columns]

# %%
true_news=true_news.drop(['name','url'],axis=1)
fake_news=fake_news.drop(['url'],axis=1)

# %%
fake_news=fake_news.dropna()
true_news=true_news.dropna()
true_news
# Out:
#                                      short_description  ...                                   long_description
# 3    किसी से पूछा जाए कि दिल्ली में पहली गणतंत्र दि...  ...  26 जनवरी: गणतंत्र दिवस की पहली परेड कहां हुई थ...
# 4    वेब सिरीज़ तांडव को लेकर जारी विवाद पर आज का क...  ...  कार्टून: सख़्त ज़रूरत है\n4 घंटे पहले\nइमेज स्...
# 5    बेका समझौता, H1B वीज़ा के नए नियम , क्वॉड समूह...  ...  डोनाल्ड ट्रंप ने भारत में मोदी सरकार की मुश्कि...
# 6    विपक्षी कांग्रेस पार्टी ने सरकार से स्थिति स्प...  ...  चीन और भारत के बीच अरुणाचल प्रदेश को लेकर क्या...
# 7    बाइडन-कमला हैरिस की टीम ने अपने प्रशासन के लिए...  ...  बाइडन प्रशासन में छाये रह सकते हैं भारतीय मूल ...
# ..                                                 ...  ...                                                ...
# 874  पाकिस्तान में कभी एक दूसरे की धुर-विरोधी रही व...  ...  पाकिस्तान: इमरान ख़ान सरकार को सत्ता से हटाने ...
# 875  तेलंगाना, आंध्र प्रदेश, केरल, कर्नाटक, ओडिशा, ...  ...  दक्षिण भारत में भारी बारिश, कम-से-कम 30 लोगों ...
# 879  बिहार के जातिगत समीकरणों की बात बहुत होती है, ...  ...  बिहार: जातीय समीकरणों और बीजेपी के हिंदुत्व का...
# 880  गुरुवार से कई राज्यों में सात महीने के बाद सिन...  ...  अनलॉक 5: आज से कहाँ-कहाँ खुल रहे हैं सिनेमाघर\...
# 881  भारतीय विदेश मंत्रालय के प्रवक्ता अनुराग श्रीव...  ...  पाकिस्तानी एनएसए के दावे पर भारत ने कहा, ये नस...
#
# [439 rows x 3 columns]

# %%
fake_news
# Out:
#                                       short_description  ...                                   long_description
# 0     बूम ने पाया कि इमरान खान भारत सरकार की आलोचना ...  ...  A video is viral with the claim that Pakistan ...
# 1     सिख समुदाय के कुछ लोगों को हिंदी साइन बोर्ड पर...  ...  सिख समुदाय के कुछ लोगों को हिंदी साइन बोर्ड पर...
# 2     सोशल मीडिया प्लेटफ़ॉर्म फ़ेसबुक और ट्विटर पर इस ...  ...  प्रधानमंत्री नरेंद्र मोदी की एक़ तस्वीर सोशल मी...
# 4     मीडिया आउटलेट्स और वायर एजेंसी ने गलत तरीके से...  ...  न्यूज़ संस्थान एशियन न्यूज़ इंटरनेशनल के साथ साथ...
# 5     यूज़र्स तस्वीर शेयर करते हुए दावा कर रहे हैं कि...  ...  सोशल मीडिया पर एक धार्मिक स्थल की तस्वीर फ़र्ज़ी...
# ...                                                 ...  ...                                                ...
# 1245  भारतीय पहलवान कविता देवी और बुल बुल के बीच हुए...  ...  सोशल मीडिया पर एक फ्री स्टाइल महिला पहलवान का ...
# 1246  बूम से बात करते हुए एसबीआई अधिकारी ने बताया कि...  ...  एटीएम मशीन के अंदर फटे नोटों की ये तस्वीर व्हा...
# 1247  बीजेपी सांसद परेश रावल एक बार फिर अपने फेक न्य...  ...  अभिनेता से सांसद बने परेश रावल ट्विटर पर फेक न...
# 1248  मार्च से लेकर मई महीने में अचानक से एक्टिव हुई...  ...  कर्नाटक चुनाव के दौर में जो ढेरों वेबसाइटस देख...
# 1249  स्वच्छ भारत मिशन के अधिकारियों के मुताबिक, साढ...  ...  प्रधानमंत्री नरेंद्र मोदी ने बिहार के मोतिहारी...
#
# [1241 rows x 3 columns]

# %%
for i in list(true_news):
  true_news[i]=true_news[i].str.replace('|', '')
  true_news[i]=true_news[i].str.replace('?', '')
  true_news[i]=true_news[i].str.replace(':', '')
  true_news[i]=true_news[i].str.replace(';', '')
  true_news[i]=true_news[i].str.replace("'", '')
  true_news[i]=true_news[i].str.replace('"', '')
  true_news[i]=true_news[i].str.replace(',', '')
  true_news[i]=true_news[i].str.replace('.', '')
  true_news[i]=true_news[i].str.replace('(', '')
  true_news[i]=true_news[i].str.replace(')', '')
  true_news[i]=true_news[i].str.replace('\n', '')
  true_news[i]=true_news[i].str.replace('&', '')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   if __name__ == '__main__':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   # This is added back by InteractiveShellApp.init_path()

# %%
for i in list(fake_news):
  fake_news[i]=fake_news[i].str.replace('|', '')
  fake_news[i]=fake_news[i].str.replace('?', '')
  fake_news[i]=fake_news[i].str.replace(':', '')
  fake_news[i]=fake_news[i].str.replace(';', '')
  fake_news[i]=fake_news[i].str.replace("'", '')
  fake_news[i]=fake_news[i].str.replace('"', '')
  fake_news[i]=fake_news[i].str.replace(',', '')
  fake_news[i]=fake_news[i].str.replace('.', '')
  fake_news[i]=fake_news[i].str.replace('(', '')
  fake_news[i]=fake_news[i].str.replace(')', '')
  fake_news[i]=fake_news[i].str.replace('\n', '')
  fake_news[i]=fake_news[i].str.replace('&', '')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   if __name__ == '__main__':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   # This is added back by InteractiveShellApp.init_path()

# %%
true_news
# Out:
#                                      short_description  ...                                   long_description
# 3    किसी से पूछा जाए कि दिल्ली में पहली गणतंत्र दि...  ...  26 जनवरी गणतंत्र दिवस की पहली परेड कहां हुई थी...
# 4    वेब सिरीज़ तांडव को लेकर जारी विवाद पर आज का क...  ...  कार्टून सख़्त ज़रूरत है4 घंटे पहलेइमेज स्रोतKi...
# 5    बेका समझौता H1B वीज़ा के नए नियम  क्वॉड समूह क...  ...  डोनाल्ड ट्रंप ने भारत में मोदी सरकार की मुश्कि...
# 6    विपक्षी कांग्रेस पार्टी ने सरकार से स्थिति स्प...  ...  चीन और भारत के बीच अरुणाचल प्रदेश को लेकर क्या...
# 7    बाइडन-कमला हैरिस की टीम ने अपने प्रशासन के लिए...  ...  बाइडन प्रशासन में छाये रह सकते हैं भारतीय मूल ...
# ..                                                 ...  ...                                                ...
# 874  पाकिस्तान में कभी एक दूसरे की धुर-विरोधी रही व...  ...  पाकिस्तान इमरान ख़ान सरकार को सत्ता से हटाने क...
# 875  तेलंगाना आंध्र प्रदेश केरल कर्नाटक ओडिशा महारा...  ...  दक्षिण भारत में भारी बारिश कम-से-कम 30 लोगों क...
# 879  बिहार के जातिगत समीकरणों की बात बहुत होती है ल...  ...  बिहार जातीय समीकरणों और बीजेपी के हिंदुत्व का ...
# 880  गुरुवार से कई राज्यों में सात महीने के बाद सिन...  ...  अनलॉक 5 आज से कहाँ-कहाँ खुल रहे हैं सिनेमाघर15...
# 881  भारतीय विदेश मंत्रालय के प्रवक्ता अनुराग श्रीव...  ...  पाकिस्तानी एनएसए के दावे पर भारत ने कहा ये नसी...
#
# [439 rows x 3 columns]

# %%
fake_news
# Out:
#                                       short_description  ...                                   long_description
# 0     बूम ने पाया कि इमरान खान भारत सरकार की आलोचना ...  ...  A video is viral with the claim that Pakistan ...
# 1     सिख समुदाय के कुछ लोगों को हिंदी साइन बोर्ड पर...  ...  सिख समुदाय के कुछ लोगों को हिंदी साइन बोर्ड पर...
# 2     सोशल मीडिया प्लेटफ़ॉर्म फ़ेसबुक और ट्विटर पर इस ...  ...  प्रधानमंत्री नरेंद्र मोदी की एक़ तस्वीर सोशल मी...
# 4     मीडिया आउटलेट्स और वायर एजेंसी ने गलत तरीके से...  ...  न्यूज़ संस्थान एशियन न्यूज़ इंटरनेशनल के साथ साथ...
# 5     यूज़र्स तस्वीर शेयर करते हुए दावा कर रहे हैं कि...  ...  सोशल मीडिया पर एक धार्मिक स्थल की तस्वीर फ़र्ज़ी...
# ...                                                 ...  ...                                                ...
# 1245  भारतीय पहलवान कविता देवी और बुल बुल के बीच हुए...  ...  सोशल मीडिया पर एक फ्री स्टाइल महिला पहलवान का ...
# 1246  बूम से बात करते हुए एसबीआई अधिकारी ने बताया कि...  ...  एटीएम मशीन के अंदर फटे नोटों की ये तस्वीर व्हा...
# 1247  बीजेपी सांसद परेश रावल एक बार फिर अपने फेक न्य...  ...  अभिनेता से सांसद बने परेश रावल ट्विटर पर फेक न...
# 1248  मार्च से लेकर मई महीने में अचानक से एक्टिव हुई...  ...  कर्नाटक चुनाव के दौर में जो ढेरों वेबसाइटस देख...
# 1249  स्वच्छ भारत मिशन के अधिकारियों के मुताबिक साढ़...  ...  प्रधानमंत्री नरेंद्र मोदी ने बिहार के मोतिहारी...
#
# [1241 rows x 3 columns]

# %%
suffixes = {
    1: ["ो", "े", "ू", "ु", "ी", "ि", "ा"],
    2: ["कर", "ाओ", "िए", "ाई", "ाए", "ने", "नी", "ना", "ते", "ीं", "ती", "ता", "ाँ", "ां", "ों", "ें"],
    3: ["ाकर", "ाइए", "ाईं", "ाया", "ेगी", "ेगा", "ोगी", "ोगे", "ाने", "ाना", "ाते", "ाती", "ाता", "तीं", "ाओं", "ाएं", "ुओं", "ुएं", "ुआं"],
    4: ["ाएगी", "ाएगा", "ाओगी", "ाओगे", "एंगी", "ेंगी", "एंगे", "ेंगे", "ूंगी", "ूंगा", "ातीं", "नाओं", "नाएं", "ताओं", "ताएं", "ियाँ", "ियों", "ियां"],
    5: ["ाएंगी", "ाएंगे", "ाऊंगी", "ाऊंगा", "ाइयाँ", "ाइयों", "ाइयां"],
}

def hi_stem(word):
    for L in 5, 4, 3, 2, 1:
        if len(word) > L + 1:
            for suf in suffixes[L]:
                if word.endswith(suf):
                    return word[:-L]
    return word

# %%
id=list(fake_news.index)
id1=list(true_news.index)

# %%
str_temp=""
count=0
for i in list(fake_news):
  count=0
  for j in list(fake_news[i]):
    for words in j.split():
      str_temp+=hi_stem(words)
      str_temp+=" "
    fake_news.loc[id[count],i]=str_temp
    str_temp=""
    count+=1

# %%
str_temp=""
count=0
for i in list(true_news):
  count=0
  for j in list(true_news[i]):
    for words in j.split():
      str_temp+=hi_stem(words)
      str_temp+=" "
    true_news.loc[id1[count],i]=str_temp
    str_temp=""
    count+=1

# %%
fake_news
# Out:
#                                       short_description  ...                                   long_description
# 0     बूम ने पाय कि इमरान खान भारत सरकार की आलोच कर ...  ...  A video is viral with the claim that Pakistan ...
# 1     सिख समुदाय के कुछ लोग को हिंद साइन बोर्ड पर का...  ...  सिख समुदाय के कुछ लोग को हिंद साइन बोर्ड पर का...
# 2     सोशल मीडिय प्लेटफ़ॉर्म फ़ेसबुक और ट्विटर पर इस द...  ...  प्रधानमंत्र नरेंद्र मोद की एक़ तस्वीर सोशल मीडि...
# 4     मीडिय आउटलेट्स और वायर एजेंस ने गलत तरीक से दा...  ...  न्यूज़ संस्थान एशियन न्यूज़ इंटरनेशनल के साथ साथ...
# 5     यूज़र्स तस्वीर शेयर कर हुए दाव कर रह हैं कि यह ...  ...  सोशल मीडिय पर एक धार्मिक स्थल की तस्वीर फ़र्ज़ द...
# ...                                                 ...  ...                                                ...
# 1245  भारतीय पहलवान कवि देव और बुल बुल के बीच हुए कु...  ...  सोशल मीडिय पर एक फ्र स्टाइल महिल पहलवान का कुश...
# 1246  बूम से बात कर हुए एसबीआई अधिकार ने बत कि ये उन...  ...  एटीएम मशीन के अंदर फट नोट की ये तस्वीर व्हाटसए...
# 1247  बीजेप सांसद परेश रावल एक बार फिर अप फेक न्यूज ...  ...  अभिने से सांसद बन परेश रावल ट्विटर पर फेक न्यू...
# 1248  मार्च से ले मई मही में अचानक से एक्टिव हुई फेक...  ...  कर्नाटक चुनाव के दौर में जो ढेर वेबसाइटस देख क...
# 1249  स्वच्छ भारत मिशन के अधिकार के मुताबिक साढ़ आठ ...  ...  प्रधानमंत्र नरेंद्र मोद ने बिहार के मोतिहार से...
#
# [1241 rows x 3 columns]

# %%
true_news
# Out:
#                                      short_description  ...                                   long_description
# 3    किस से पूछ जाए कि दिल्ल में पहल गणतंत्र दिवस प...  ...  26 जनवर गणतंत्र दिवस की पहल परेड कह हुई थीनलिन...
# 4    वेब सिरीज़ तांडव को ले जार विवाद पर आज का कार्...  ...  कार्टून सख़्त ज़रूरत है4 घंट पहलेइमेज स्रोतKir...
# 5    बेक समझौ H1B वीज़ के नए नियम क्वॉड समूह का गठन...  ...  डोनाल्ड ट्रंप ने भारत में मोद सरकार की मुश्किल...
# 6    विपक्ष कांग्रेस पार्ट ने सरकार से स्थित स्पष्ट...  ...  चीन और भारत के बीच अरुणाचल प्रदेश को ले क्य है...
# 7    बाइडन-कमल हैरिस की टीम ने अप प्रशासन के लिए भा...  ...  बाइडन प्रशासन में छाय रह सक हैं भारतीय मूल के ...
# ..                                                 ...  ...                                                ...
# 874  पाकिस्तान में कभ एक दूसर की धुर-विरोध रह विपक्...  ...  पाकिस्तान इमरान ख़ान सरकार को सत् से हट की मुह...
# 875  तेलंग आंध्र प्रदेश केरल कर्नाटक ओडिश महाराष्ट्...  ...  दक्षिण भारत में भार बारिश कम-से-कम 30 लोग की म...
# 879  बिहार के जातिगत समीकरण की बात बहुत हो है लेकिन...  ...  बिहार जातीय समीकरण और बीजेप के हिंदुत्व का दंग...
# 880  गुरुवार से कई राज्य में सात मही के बाद सिनेमाघ...  ...  अनलॉक 5 आज से कहाँ-कह खुल रह हैं सिनेमाघर15 अक...
# 881  भारतीय विदेश मंत्रालय के प्रवक् अनुराग श्रीवास...  ...  पाकिस्ता एनएसए के दाव पर भारत ने कह ये नसीहत अ...
#
# [439 rows x 3 columns]

# %%
stop=open('/content/FakeNewsDetection/final_stopwords.txt')
stopwords=[]
for x in stop:
  x = x.replace('\n', '')
  stopwords.append(x)

# %%
stopwords
# Out:
# ['मैं',
#  'मुझको',
#  'मेरा',
#  'अपने आप को',
#  'हमने',
#  'हमारा',
#  'अपना',
#  'हम',
#  'आप',
#  'आपका',
#  'तुम्हारा',
#  'अपने आप',
#  'स्वयं',
#  'वह',
#  'इसे',
#  'उसके',
#  'खुद को',
#  'कि वह',
#  'उसकी',
#  'उसका',
#  'खुद ही',
#  'यह',
#  'इसके',
#  'उन्होने',
#  'अपने',
#  'क्या',
#  'जो',
#  'किसे',
#  'किसको',
#  'कि',
#  'ये',
#  'हूँ',
#  'होता है',
#  'रहे',
#  'थी',
#  'थे',
#  'होना',
#  'गया',
#  'किया जा रहा है',
#  'किया है',
#  'है',
#  'पडा',
#  'होने',
#  'करना',
#  'करता है',
#  'किया',
#  'रही',
#  'एक',
#  'लेकिन',
#  'अगर',
#  'या',
#  'क्यूंकि',
#  'जैसा',
#  'जब तक',
#  'जबकि',
#  'की',
#  'पर',
#  'द्वारा',
#  'के लिए',
#  'साथ',
#  'के बारे में',
#  'खिलाफ',
#  'बीच',
#  'में',
#  'के माध्यम से',
#  'दौरान',
#  'से पहले',
#  'के बाद',
#  'ऊपर',
#  'नीचे',
#  'को',
#  'से',
#  'तक',
#  'से नीचे',
#  'करने में',
#  'निकल',
#  'बंद',
#  'से अधिक',
#  'तहत',
#  'दुबारा',
#  'आगे',
#  'फिर',
#  'एक बार',
#  'यहाँ',
#  'वहाँ',
#  'कब',
#  'कहाँ',
#  'क्यों',
#  'कैसे',
#  'सारे',
#  'किसी',
#  'दोनो',
#  'प्रत्येक',
#  'ज्यादा',
#  'अधिकांश',
#  'अन्य',
#  'में कुछ',
#  'ऐसा',
#  'में कोई',
#  'मात्र',
#  'खुद',
#  'समान',
#  'इसलिए',
#  'बहुत',
#  'सकता',
#  'जायेंगे',
#  'जरा',
#  'चाहिए',
#  'अभी',
#  'और',
#  'कर दिया',
#  'रखें',
#  'का',
#  'हैं',
#  'इस',
#  'होता',
#  'करने',
#  'ने',
#  'बनी',
#  'तो',
#  'ही',
#  'हो',
#  'इसका',
#  'था',
#  'हुआ',
#  'वाले',
#  'बाद',
#  'लिए',
#  'सकते',
#  'इसमें',
#  'दो',
#  'वे',
#  'करते',
#  'कहा',
#  'वर्ग',
#  'कई',
#  'करें',
#  'होती',
#  'अपनी',
#  'उनके',
#  'यदि',
#  'हुई',
#  'जा',
#  'कहते',
#  'जब',
#  'होते',
#  'कोई',
#  'हुए',
#  'व',
#  'जैसे',
#  'सभी',
#  'करता',
#  'उनकी',
#  'तरह',
#  'उस',
#  'आदि',
#  'इसकी',
#  'उनका',
#  'इसी',
#  'पे',
#  'तथा',
#  'भी',
#  'परंतु',
#  'इन',
#  'कम',
#  'दूर',
#  'पूरे',
#  'गये',
#  'तुम',
#  'मै',
#  'यहां',
#  'हुये',
#  'कभी',
#  'अथवा',
#  'गयी',
#  'प्रति',
#  'जाता',
#  'इन्हें',
#  'गई',
#  'अब',
#  'जिसमें',
#  'लिया',
#  'बड़ा',
#  'जाती',
#  'तब',
#  'उसे',
#  'जाते',
#  'लेकर',
#  'बड़े',
#  'दूसरे',
#  'जाने',
#  'बाहर',
#  'स्थान',
#  'उन्हें ',
#  'गए',
#  'ऐसे',
#  'जिससे',
#  'समय',
#  'दोनों',
#  'किए',
#  'रहती',
#  'इनके',
#  'इनका',
#  'इनकी',
#  'सकती',
#  'आज',
#  'कल',
#  'जिन्हें',
#  'जिन्हों',
#  'तिन्हें',
#  'तिन्हों',
#  'किन्हों',
#  'किन्हें',
#  'इत्यादि',
#  'इन्हों',
#  'उन्हों',
#  'बिलकुल',
#  'निहायत',
#  'इन्हीं',
#  'उन्हीं',
#  'जितना',
#  'दूसरा',
#  'कितना',
#  'साबुत',
#  'वग़ैरह',
#  'कौनसा',
#  'लिये',
#  'दिया',
#  'जिसे',
#  'तिसे',
#  'काफ़ी',
#  'पहले',
#  'बाला',
#  'मानो',
#  'अंदर',
#  'भीतर',
#  'पूरा',
#  'सारा',
#  'उनको',
#  'वहीं',
#  'जहाँ',
#  'जीधर',
#  '\ufeffके',
#  'एवं',
#  'कुछ',
#  'कुल',
#  'रहा',
#  'जिस',
#  'जिन',
#  'तिस',
#  'तिन',
#  'कौन',
#  'किस',
#  'संग',
#  'यही',
#  'बही',
#  'उसी',
#  'मगर',
#  'कर',
#  'मे',
#  'एस',
#  'उन',
#  'सो',
#  'अत']

# %%
from numpy import unicode
str_temp=""
count=0
for i in list(fake_news):
  count=0
  for j in list(fake_news[i]):
    for words in j.split():
      if unicode(words) not in stopwords:
        str_temp+=words
        str_temp+=" "
    fake_news.loc[id[count],i]=str_temp
    str_temp=""
    count+=1

# %%
fake_news
# Out:
#                                       short_description  ...                                   long_description
# 0     बूम पाय इमरान खान भारत सरकार आलोच रह वर्तमान श...  ...  A video is viral with the claim that Pakistan ...
# 1     सिख समुदाय के लोग हिंद साइन बोर्ड कालिख पोत दि...  ...  सिख समुदाय के लोग हिंद साइन बोर्ड कालिख पोत दि...
# 2     सोशल मीडिय प्लेटफ़ॉर्म फ़ेसबुक ट्विटर दाव के बड़ ...  ...  प्रधानमंत्र नरेंद्र मोद एक़ तस्वीर सोशल मीडिय ख़...
# 4     मीडिय आउटलेट्स वायर एजेंस गलत तरीक दाव किय पाक...  ...  न्यूज़ संस्थान एशियन न्यूज़ इंटरनेशनल के मुख्य ध...
# 5     यूज़र्स तस्वीर शेयर दाव रह तस्वीर पुरा दिल्ल रे...  ...  सोशल मीडिय धार्मिक स्थल तस्वीर फ़र्ज़ दाव के वाय...
# ...                                                 ...  ...                                                ...
# 1245  भारतीय पहलवान कवि देव बुल बुल के कुश् मुकाबल व...  ...  सोशल मीडिय फ्र स्टाइल महिल पहलवान कुश् मुकाबल ...
# 1246  बूम बात एसबीआई अधिकार बत उनक एटीएम क्योंक ब्रा...  ...  एटीएम मशीन के फट नोट तस्वीर व्हाटसएप सोशल मीडि...
# 1247  बीजेप सांसद परेश रावल बार अप फेक न्यूज फैल प्र...  ...  अभिने सांसद बन परेश रावल ट्विटर फेक न्यूज के श...
# 1248  मार्च ले मई मही अचानक एक्टिव फेक न्यूज वेबसाइट...  ...  कर्नाटक चुनाव के दौर ढेर वेबसाइटस देख मिल वो ऑ...
# 1249  स्वच्छ भारत मिशन के अधिकार के मुताबिक साढ़ आठ ...  ...  प्रधानमंत्र नरेंद्र मोद बिहार के मोतिहार दाव क...
#
# [1241 rows x 3 columns]

# %%
from numpy import unicode
str_temp=""
count=0
for i in list(true_news):
  count=0
  for j in list(true_news[i]):
    for words in j.split():
      if unicode(words) not in stopwords:
        str_temp+=words
        str_temp+=" "
    true_news.loc[id1[count],i]=str_temp
    str_temp=""
    count+=1

# %%
true_news
# Out:
#                                      short_description  ...                                   long_description
# 3    पूछ जाए दिल्ल पहल गणतंत्र दिवस परेड कह इसक जवा...  ...  26 जनवर गणतंत्र दिवस पहल परेड कह थीनलिन चौहानव...
# 4               वेब सिरीज़ तांडव ले जार विवाद कार्टून   ...  कार्टून सख़्त ज़रूरत है4 घंट पहलेइमेज स्रोतKir...
# 5    बेक समझौ H1B वीज़ के नए नियम क्वॉड समूह गठन - ...  ...  डोनाल्ड ट्रंप भारत मोद सरकार मुश्किल बढ़ दियास...
# 6    विपक्ष कांग्रेस पार्ट सरकार स्थित स्पष्ट कह दू...  ...  चीन भारत के अरुणाचल प्रदेश ले क्य ताज़ विवादसल...
# 7    बाइडन-कमल हैरिस टीम अप प्रशासन के भारतीय मूल क...  ...  बाइडन प्रशासन छाय रह सक भारतीय मूल के अमेरिकीज...
# ..                                                 ...  ...                                                ...
# 874  पाकिस्तान कभ दूसर धुर-विरोध रह विपक्ष पार्ट इम...  ...  पाकिस्तान इमरान ख़ान सरकार सत् हट मुहिम विपक्ष...
# 875  तेलंग आंध्र प्रदेश केरल कर्नाटक ओडिश महाराष्ट्...  ...  दक्षिण भारत भार बारिश कम-से-कम 30 लोग मौत15 अक...
# 879  बिहार के जातिगत समीकरण बात लंब बीजेप हिंद पहचा...  ...  बिहार जातीय समीकरण बीजेप के हिंदुत्व दंगल चुना...
# 880  गुरुवार राज्य सात मही के सिनेमाघर मल्टीप्लेक्स...  ...  अनलॉक 5 कहाँ-कह खुल रह सिनेमाघर15 अक्टूबर 2020...
# 881  भारतीय विदेश मंत्रालय के प्रवक् अनुराग श्रीवास...  ...  पाकिस्ता एनएसए के दाव भारत कह नसीहत अप सरकार र...
#
# [439 rows x 3 columns]

# %%
true_news.to_csv('true_news.csv')
fake_news.to_csv('fake_news.csv')

# %%
#@title not imp
len(true_news), len(fake_news)
fake_news = fake_news.head(len(true_news))
len(true_news), len(fake_news)

# assign labels
fake_news['label'] = 1
true_news['label'] = 0

# join true and false dataset
news = pd.concat([fake_news, true_news])
from sklearn.utils import shuffle
news = shuffle(news)
